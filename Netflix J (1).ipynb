# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import csv

import os

# %%
my_conn=create_engine('mysql+mysqldb://root:123456@localhost/bajaj')

# %%
my_conn
# Out:
# Engine(mysql+mysqldb://root:***@localhost/bajaj)

# %%
os.chdir('C:\\Users\\user\\Downloads')

# %%
df=pd.read_csv('Netflix Dataset.csv')

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.loc[(df['Title']=='House of Cards'),['Title','Show_Id','Director']]
# Out:
#                Title Show_Id  \
# 2832  House of Cards   s2833
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
df[df['Title']=='House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
df['Release_Date'][:-4]
# Out:
# 0         August 14, 2020
# 1       December 23, 2016
# 2       December 20, 2018
# 3       November 16, 2017
# 4         January 1, 2020
#               ...
# 7780     November 1, 2019
# 7781    November 26, 2019
# 7782         July 1, 2018
# 7783     January 11, 2020
# 7784     October 19, 2020
# Name: Release_Date, Length: 7785, dtype: object

# %%
#df['Date_N']=pd.to_datetime(df['Release_Date']).dt.strftime("%d-%m-%Y")
df['Date_N']=pd.to_datetime((df.Release_Date+df.Release_Date).iloc[8730:8736],format='%Y-%m-%d %H:%M%Z', errors='raise')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  Date_N        0 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 730.3+ KB

# %%
df['Date_N']=df['Release_Date']

# %%
df['Date_N']=df['Release_Date'].str[-4:]

# %%
df['Date_N'].value_counts()
# Out:
# Date_N
# 2019    2154
# 2020    2010
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: count, dtype: int64

# %%
df['Date_N'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Date_N',data=df)
plt.show()

# %% [markdown]
# # Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: count, dtype: int64

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='Category',data=df)
plt.show()

# %% [markdown]
# # Q. 4) Show all the Movies that were released in year 2020.

# %%
df.loc[(df['Category']=='Movie') & (df['Date_N']=='2020') ,['Category','Date_N','Title']]
# Out:
#      Category Date_N                                    Title
# 4       Movie   2020                                       21
# 6       Movie   2020                                      122
# 14      Movie   2020                                     3022
# 27      Movie   2020                                   #Alive
# 28      Movie   2020            #AnneFrank - Parallel Stories
# ...       ...    ...                                      ...
# 7762    Movie   2020                                Zaki Chan
# 7783    Movie   2020                                     Zoom
# 7784    Movie   2020                                     Zozo
# 7786    Movie   2020                        Zulu Man in Japan
# 7788    Movie   2020  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
# [1313 rows x 3 columns]

# %%
df[(df['Category']=='Movie') & (df['Date_N']=='2020')]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# # Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df.loc[(df['Category']=='TV Show') & (df['Country']=='India'),['Category','Country','Title']]
# Out:
#      Category Country                               Title
# 86    TV Show   India        21 Sarfarosh: Saragarhi 1897
# 132   TV Show   India                           7 (Seven)
# 340   TV Show   India                        Agent Raghav
# 364   TV Show   India                        Akbar Birbal
# 533   TV Show   India                 Anjaan: Rural Myths
# ...       ...     ...                                 ...
# 6249  TV Show   India                The Creative Indians
# 6400  TV Show   India  The Golden Years with Javed Akhtar
# 6469  TV Show   India              The House That Made Me
# 7294  TV Show   India                          Typewriter
# 7705  TV Show   India                     Yeh Meri Family
#
# [71 rows x 3 columns]

# %%
df[(df['Category']=='TV Show') & (df['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %% [markdown]
# # Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df[(df['Category']=='Movie') & (df['Type'].str.contains('Comed') | (df['Country']=='United Kingdom'))]
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 19       s20    Movie                                '89                 NaN
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %% [markdown]
# # Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df[df['Cast'].str.contains('Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df[df['Cast'].str.contains('Cruise')]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %% [markdown]
# @ Cannot mask with non-boolean array containing NA / NaN values ,@$
#
# - Hence we create a copy for the data frame and drop all null values

# %%
df_copy=df

# %%
df_copy=df_copy.dropna()

# %%
df_copy[df_copy['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description Date_N
# 3860  Through chance, human action, past history and...   2020
# 5071  A fast-talking yuppie is forced to slow down w...   2019

# %% [markdown]
# # Q. 9) What are the different Ratings defined by Netflix ?

# %%
df['Rating'].unique()

# %%
df[df['Rating'].isna()]

# %%
df['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %% [markdown]
# # Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')][['Title','Category']].shape
# Out:
# (11, 2)

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')][['Title','Category']].groupby('Category').count()
# Out:
#           Title
# Category
# Movie        11

# %% [markdown]
# # Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Date_N']>'2018')][['Title','Category']].shape
# Out:
# (1, 2)

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Date_N']>'2018')][['Title','Category']].groupby('Category').count()
# Out:
#           Title
# Category
# TV Show       1

# %% [markdown]
# # Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# - Here we can see Duration column contains in multiple foramts like minutes and Seasons, Hence we create 2 extra columns for each type

# %%
df[["Minutes","Unit"]]=df['Duration'].str.split(' ',expand=True)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
max_duration_Minutes=df['Minutes'].max()

# %%
print('The maximun duration of Movie/Show on Netflix :',df['Minutes'].max())
# Out:
# The maximun duration of Movie/Show on Netflix : 99

# %%
df[df['Minutes']==max_duration_Minutes]
# Out:
#      Show_Id Category                                        Title  \
# 27       s28    Movie                                       #Alive
# 33       s34    Movie                                 #realityhigh
# 42       s43    Movie                  Çok Filim Hareketler Bunlar
# 121     s122    Movie                               50 First Dates
# 147     s148    Movie      A Babysitter's Guide to Monster Hunting
# ...      ...      ...                                          ...
# 7449   s7448    Movie                                          VS.
# 7527   s7526    Movie                        Welcome Mr. President
# 7559   s7558    Movie                         What Keeps You Alive
# 7638   s7637    Movie  Winter on Fire: Ukraine's Fight for Freedom
# 7784   s7783    Movie                                         Zozo
#
#                Director                                               Cast  \
# 27               Cho Il                           Yoo Ah-in, Park Shin-hye
# ...

# %% [markdown]
# # Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.loc[(df['Category']=='TV Show'),['Country','Title']].groupby('Country').count().sort_values(by='Title',ascending=False)
# Out:
#                                 Title
# Country
# United States                     705
# United Kingdom                    204
# Japan                             157
# South Korea                       147
# India                              71
# ...                               ...
# Mexico, Spain                       1
# China, Hong Kong                    1
# Mauritius, South Africa             1
# Malaysia, Singapore, Hong Kong      1
# Uruguay, Germany                    1
#
# [183 rows x 1 columns]

# %%
df_TV_Show=df[df['Category']=='TV Show']

# %%
df_TV_Show.groupby('Country')['Title'].count().sort_values(ascending=False).reset_index().head(1)
# Out:
#          Country  Title
# 0  United States    705

# %% [markdown]
# # Q. 12) How can we sort the dataset by Year ?

# %%
df_copy['Date_N'].dropna(inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1052\2965933380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['Date_N'].dropna(inplace=True)

# %% [markdown]
# - Date_N columns is object type hence sorting cannot be possible for null values, hence i drop null values
# - We can also use by converting it into int/float type

# %%
df_copy['Date_N'].isna().sum()
# Out:
# 0

# %%
df_copy.sort_values(by='Date_N',ascending=False)
# Out:
#      Show_Id Category                        Title                Director  \
# 1739   s1740    Movie  Dhobi Ghat (Mumbai Diaries)               Kiran Rao
# 1690   s1691    Movie                  Delhi Belly             Abhinay Deo
# 2413   s2414    Movie                Gimme Shelter              Ron Krauss
# 6289   s6289    Movie                 The Departed         Martin Scorsese
# 7571   s7570    Movie  What Would Sophia Loren Do?           Ross Kauffman
# ...      ...      ...                          ...                     ...
# 5833   s5833    Movie               Strange Voices  Arthur Allan Seidelman
# 3840   s3841    Movie  Mad Ron's Prevues from Hell              Jim Monaco
# 5766   s5766    Movie                     Splatter               Joe Dante
# 3248   s3249    Movie      Just Another Love Story            Ole Bornedal
# 7115   s7114    Movie         To and From New York    Sorin Dan Mihalcescu
#
#                                                    Cast  \
# ...

# %%
pd.to_numeric(df['Date_N'])
# Out:
# 0       2020.0
# 1       2016.0
# 2       2018.0
# 3       2017.0
# 4       2020.0
#          ...
# 7784    2020.0
# 7785    2019.0
# 7786    2020.0
# 7787    2020.0
# 7788    2020.0
# Name: Date_N, Length: 7789, dtype: float64

# %%
df.sort_values(by='Date_N',ascending=False).head()
# Out:
#      Show_Id Category              Title                      Director  \
# 7353   s7352    Movie            Unknown            Jaume Collet-Serra
# 2013   s2014    Movie   Enter the Dragon                 Robert Clouse
# 2349   s2350    Movie          Gangaajal                   Prakash Jha
# 1497   s1498    Movie     Cool Hand Luke              Stuart Rosenberg
# 1194   s1195    Movie  Can't Hardly Wait  Harry Elfont, Deborah Kaplan
#
#                                                    Cast  \
# 7353  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
# 2349  Ajay Devgn, Gracy Singh, Mohan Agashe, Mohan J...
# 1497  Paul Newman, George Kennedy, J.D. Cannon, Lou ...
# 1194  Jennifer Love Hewitt, Ethan Embry, Charlie Kor...
#
#                                              Country     Release_Date Rating  \
# 7353  United Kingdom, Germany, France, United States  January 1, 2021  PG-13
# ...

# %% [markdown]
# # Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df[(df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %% [markdown]
# # Q.14 Whos is the Most movies/Shows Directed

# %%
df['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Elle Callahan              1
# Sam Dunn                   1
# Name: count, Length: 4050, dtype: int64

# %%
df[['Rating','Director']].groupby(['Director','Rating']).value_counts().sort_values(ascending=False).reset_index()
# Out:
#                     Director Rating  count
# 0     Raúl Campos, Jan Suter  TV-MA     17
# 1               Marcus Raboy  TV-MA     13
# 2                  Jay Karas  TV-MA     10
# 3                Jay Chapman  TV-MA     10
# 4          Quentin Tarantino      R      8
# ...                      ...    ...    ...
# 4564          Jeffrey Walker  TV-MA      1
# 4565          Jeffrey Walker  TV-PG      1
# 4566          Jehane Noujaim  TV-MA      1
# 4567          Jelle de Jonge  TV-MA      1
# 4568      Kieran Darcy-Smith      R      1
#
# [4569 rows x 3 columns]

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_N Minutes     Unit
# 0  In a future where the elite inhabit an island ...   2020       4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...   2016      93      min

# %%
df['Type'].unique()
# Out:
# array(['International TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#        'Dramas, International Movies',
#        'Horror Movies, International Movies',
#        'Action & Adventure, Independent Movies, Sci-Fi & Fantasy',
#        'Dramas', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, Thrillers',
#        'Crime TV Shows, International TV Shows, TV Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Documentaries, International Movies, Sports Movies',
#        'Independent Movies, Sci-Fi & Fantasy, Thrillers',
#        'Dramas, International Movies, Thrillers',
#        'International TV Shows, TV Dramas',
#        'Comedies, Dramas, Independent Movies', 'Sports Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Action & Adventure, Dramas, International Movies',
#        'Anime Series, International TV Shows', 'Documentaries',
# ...

# %% [markdown]
# ## Q.15) Movies/TV Shows ratings in India and Other than india

# %%
df_india=df[df['Country']=='India']

# %%
df_india
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
df_other=df[df['Country']!='India']
df_other.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Rating',hue='Category',data=df_india)
plt.xticks(rotation=45,fontsize=10)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Rating',hue='Category',data=df_other)
plt.xticks(rotation=80,fontsize=10)
plt.show()
